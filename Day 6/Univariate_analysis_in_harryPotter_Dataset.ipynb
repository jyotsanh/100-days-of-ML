# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Harry.csv",sep=(";"))

# %%
df.shape
# Out:
# (140, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            140 non-null    int64
#  1   Name          140 non-null    object
#  2   Gender        139 non-null    object
#  3   Job           121 non-null    object
#  4   House         101 non-null    object
#  5   Wand          132 non-null    object
#  6   Patronus      130 non-null    object
#  7   Species       140 non-null    object
#  8   Blood status  123 non-null    object
#  9   Hair colour   123 non-null    object
#  10  Eye colour    86 non-null     object
#  11  Loyalty       89 non-null     object
#  12  Skills        113 non-null    object
#  13  Birth         127 non-null    object
#  14  Death         42 non-null     object
# dtypes: int64(1), object(14)
# memory usage: 16.5+ KB

# %%
df.sample(5)
# Out:
#       Id                     Name  Gender  \
# 22    23               Katie Bell  Female
# 138  139                    Dobby    Male
# 104  105  Fleur Isabelle Delacour  Female
# 124  125     Albus Severus Potter    Male
# 99   100   Cornelius Oswald Fudge    Male
#
#                                                    Job  \
# 22                                             Student
# 138  Malfoy family's house-elf (? - 1993),\nHogwart...
# 104              Part-time at Gringotts Wizarding Bank
# 124                                            Student
# 99                                  Minister for Magic
#
#                             House                       Wand       Patronus  \
# 22                     Gryffindor                    Unknown        Unknown
# 138                           NaN                        NaN            NaN
# 104  Beauxbatons Academy of Magic  9½", Rosewood, veela hair  Non-corporeal
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# Name             0
# Gender           1
# Job             19
# House           39
# Wand             8
# Patronus        10
# Species          0
# Blood status    17
# Hair colour     17
# Eye colour      54
# Loyalty         51
# Skills          27
# Birth           13
# Death           98
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Out:
#              Id
# count  140.0000
# mean    70.5000
# std     40.5586
# min      1.0000
# 25%     35.7500
# 50%     70.5000
# 75%    105.2500
# max    140.0000

# %% [markdown]
# # Categorical data

# %%
sns.countplot(x=df['House'])
# Out:
# <AxesSubplot: xlabel='House', ylabel='count'>

# %%
sns.countplot(x=df['Species'])
# Out:
# <AxesSubplot: xlabel='Species', ylabel='count'>

# %%
df['Eye colour'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='Eye colour'>
