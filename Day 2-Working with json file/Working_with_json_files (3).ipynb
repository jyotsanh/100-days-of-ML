# %%
import pandas as pd

# %% [markdown]
# # Working with json

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# # Fetch json data from url

# %%
#url='http://facebook.com'
#pd.read_json(url)

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 11.9/11.9 MB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp310-cp310-win_amd64.whl size=247947 sha256=6dd8eadd8ad78352fb4d176bf765ec9a71c5ec6008227420749813055a53eeab
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\3e\7f\a3\928a40d1ffd01dd16057f308042377afc505d56145375adf40
# Successfully built mysql.connector
# ...

# %%
import mysql.connector as sq

# %%
var=sq.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'",var)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11156\917730477.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'",var)
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# ...

# %% [markdown]
# # Country with LifeExpectancy more than 60

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy >60",var)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11156\4214995166.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy >60",var)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# ...

# %%
pd.read_sql_query("SELECT * FROM countrylanguage",var)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11236\2335746958.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM countrylanguage",var)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]

# %%
pd.read_sql_query("SELECT * FROM countrylanguage WHERE Language LIKE 'English'",var)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11236\260284087.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM countrylanguage WHERE Language LIKE 'English'",var)
#    CountryCode Language IsOfficial  Percentage
# 0          ABW  English          F         9.5
# 1          AIA  English          T         0.0
# 2          ANT  English          F         7.8
# 3          ASM  English          T         3.1
# 4          ATG  English          T         0.0
# 5          AUS  English          T        81.2
# 6          BHR  English          F         0.0
# 7          BLZ  English          T        50.8
# 8          BMU  English          T       100.0
# 9          BRB  English          T         0.0
# 10         BRN  English          F         3.1
# 11         CAN  English          T        60.4
# ...
