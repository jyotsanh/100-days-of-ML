# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])

# %%
df.columns=[['Class Lables','Alchol','Malic Acid']]

# %%
df.sample(6)
# Out:
#    Class Lables Alchol Malic Acid
# 23            1  12.85       1.60
# 84            2  11.84       0.89
# 48            1  14.10       2.02
# 41            1  13.41       3.84
# 73            2  12.99       1.67
# 0             1  14.23       1.71

# %%
sns.kdeplot(df['Alchol'])
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.kdeplot(df['Malic Acid'])
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
plt.scatter(df['Alchol'],df['Malic Acid'])

# %%
df['Class Lables'].sample(5)
# Out:
#     Class Lables
# 41             1
# 175            3
# 132            3
# 101            2
# 166            3

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['Alchol','Malic Acid']]
y=df['Class Lables']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_test.shape,x_train.shape
# Out:
# ((54, 2), (124, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
xtrain_scaled = scaler.fit_transform(x_train)
xtest_scaled = scaler.fit_transform(x_test)

# %%
xtrain_scaled
# Out:
# array([[0.59210526, 0.17786561],
#        [0.72368421, 0.39920949],
#        [0.7       , 0.49802372],
#        [1.        , 0.17786561],
#        [0.34210526, 0.07114625],
#        [0.38947368, 0.19565217],
#        [0.39210526, 0.33399209],
#        [0.53684211, 0.15019763],
#        [0.36578947, 0.17193676],
#        [0.41315789, 0.33992095],
#        [0.25526316, 0.53162055],
#        [0.32105263, 0.62055336],
#        [0.67105263, 0.36363636],
#        [0.70789474, 0.13636364],
#        [0.71052632, 0.15019763],
#        [0.43947368, 0.55533597],
#        [0.20526316, 0.27272727],
#        [0.20789474, 0.14426877],
#        [0.34210526, 0.04940711],
#        [0.63684211, 0.58498024],
#        [0.73421053, 0.19960474],
#        [0.47894737, 0.16996047],
#        [0.26578947, 0.70355731],
#        [0.62631579, 0.61264822],
#        [0.53157895, 0.20355731],
#        [0.78684211, 0.18577075],
#        [0.71315789, 0.18379447],
#        [0.33157895, 0.48023715],
# ...

# %%
#Numpy array so we need to convert this into pandas dataframe

# %%
xtrain_scaled = pd.DataFrame(xtrain_scaled,columns=x.columns)
xtest_scaled = pd.DataFrame(xtest_scaled,columns=x.columns)

# %%
xtest_scaled.sample(6)
# Out:
#       Alchol Malic Acid
# 30  0.815700   0.749415
# 18  0.665529   0.700234
# 21  0.812287   0.170960
# 7   0.624573   0.168618
# 34  0.935154   0.156909
# 29  0.808874   0.194379

# %%
x_train.describe()
# Out:
#            Alchol  Malic Acid
# count  124.000000  124.000000
# mean    12.964839    2.278065
# std      0.824006    1.104796
# min     11.030000    0.740000
# 25%     12.330000    1.592500
# 50%     12.980000    1.845000
# 75%     13.622500    2.845000
# max     14.830000    5.800000

# %%
xtrain_scaled.describe()
# Out:
#            Alchol  Malic Acid
# count  124.000000  124.000000
# mean     0.509168    0.303965
# std      0.216844    0.218339
# min      0.000000    0.000000
# 25%      0.342105    0.168478
# 50%      0.513158    0.218379
# 75%      0.682237    0.416008
# max      1.000000    1.000000

# %%
plt.scatter(x_train['Alchol'],x_train['Malic Acid'])

# %%
plt.scatter(xtrain_scaled['Alchol'],xtrain_scaled['Malic Acid'],color='Red')

# %%
from sklearn.preprocessing import RobustScaler

# %%
Rob = RobustScaler()

# %%
Rob.fit(x_train)
# Out:
# RobustScaler()

# %%
robbedX=Rob.fit_transform(x_train)
robbedXt=Rob.fit_transform(x_test)

# %%
robbedX=pd.DataFrame(robbedX,columns=x_train.columns)
robbedXt=pd.DataFrame(robbedXt,columns=x_test.columns)

# %%
plt.scatter(robbedX['Alchol'],robbedX['Malic Acid'])
